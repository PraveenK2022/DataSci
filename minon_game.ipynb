# %%
def minion_game(string):
    s=[i for i in string]
    lst=['a','e','i','o','u','A','E','I','O','U']
    Stuart = []
    Kevin = []
    for a in range(len(s)):
        if s[a] in lst:
            Kevin.extend(str_split(s[a:len(s)]))
        else:
            Stuart.extend(str_split(s[a:len(s)]))
    if len(Stuart) > len(Kevin) : print("Stuart ", len(Stuart))
    elif len(Stuart) == len(Kevin) : print("Draw")
    else: print("Kevin ", len(Kevin))

def str_split(y):
    res=[];s=""
    for i in range(len(y)):
        s=s+y[i]
        res.append(s)
    return(res)
    
minion_game("...")

# %%
def minion_game(string):
    vowels = 'AEIOU'
    s=[i for i in string]
    a = 0
    b = 0
    for i in range(len(s)):
        if s[i] in vowels:
            print((len(s)-i))
            a += (len(s)-i)
        else:
            print("b=",b)

    if a > b:
        print ("Kevin", a)
    elif a < b:
        print ("Stuart", b)
    else:
        print ("Draw")
        
minion_game("BANANA")
# Out:
# b= 0
# 5
# b= 0
# 3
# b= 0
# 1
# Kevin 9

# %%
a=0
a+=1
print(a)
# Out:
# 1
